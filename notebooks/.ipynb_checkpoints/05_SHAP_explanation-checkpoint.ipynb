# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.52.0)
# Requirement already satisfied: numpy>=2 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (2.4.2)
# Requirement already satisfied: scipy in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (1.17.1)
# Requirement already satisfied: scikit-learn in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (1.8.0)
# Requirement already satisfied: pandas in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (2.3.3)
# Requirement already satisfied: tqdm>=4.27.0 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (4.68.4)
# Requirement already satisfied: packaging>20.9 in C:\Users\sauri\AppData\Roaming\Python\Python314\site-packages (from shap) (26.0)
# Requirement already satisfied: slicer==0.0.8 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (0.66.0)
# Requirement already satisfied: llvmlite in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (0.48.0)
# Requirement already satisfied: cloudpickle in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: colorama in C:\Users\sauri\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\sauri\AppData\Roaming\Python\Python314\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\sauri\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\sauri\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn->shap) (3.6.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import shap
import joblib
import pandas as pd
import matplotlib.pyplot as plt

# load model and data
model = joblib.load('../models/final_gradient_boost_model.pkl')
X_test = pd.read_csv('../data/X_test_scaled.csv')

# initialize tree explainer for gradient boosting
explainer = shap.TreeExplainer(model)
shap_values = explainer(X_test)

# global explanation summary plot
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test, show=False)
plt.title("Global Feature Importance (SHAP Summary)")
plt.tight_layout()
plt.show()

# local explanation for the very first review in test set
print("Explaining review prediction index 0:")
shap.plots.waterfall(shap_values[0])
# Out:
# Explaining review prediction index 0:
